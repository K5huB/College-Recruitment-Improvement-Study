# %% [markdown]
# # Kabir Sinha
# ## CMP 262
# ### Project 1 - Data Exploration/Cleaning
# ### Investigate/manipulate the data from a 2023 student survey

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Non-Majors Survey Results - Fall 2023.csv")

# %% [markdown]
# ## Exploration

# %%
df.describe
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# count                                         105.000000
# mean                                            2.495238
# std                                             1.136152
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000

# %%
df.columns #all column names
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
df.shape #database dimensions
# Out:
# (105, 96)

# %%
df.dtypes #data types of each column
# Out:
# Timestamp                                                                                                                                    object
# Which course are you currently enrolled in?                                                                                                  object
# How did you hear about County College of Morris? [CCM Web site]                                                                              object
# How did you hear about County College of Morris? [Social Media]                                                                              object
# How did you hear about County College of Morris? [Community Event]                                                                           object
#                                                                                                                                               ...
# ...

# %%
df.head() #first 5 database entries
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0   2023/09/05 9:36:31 PM EST         CMP 101 Computer Information Literacy
# 1   2023/09/05 9:42:31 PM EST         CMP 101 Computer Information Literacy
# 2  2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 3  2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 4  2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                 No
# ...

# %%
df.tail() #last 5 database entries
# Out:
#                       Timestamp  Which course are you currently enrolled in?  \
# 100   2023/09/19 6:04:34 PM EST  CMP 135 Computer Concepts with Applications
# 101   2023/09/19 6:05:55 PM EST        CMP 101 Computer Information Literacy
# 102   2023/09/19 6:07:54 PM EST  CMP 135 Computer Concepts with Applications
# 103   2023/09/19 6:08:11 PM EST  CMP 135 Computer Concepts with Applications
# 104  2023/09/19 10:44:14 PM EST  CMP 135 Computer Concepts with Applications
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 100                                                 No
# 101                                                Yes
# 102                                                Yes
# 103                                                Yes
# 104                                       Don't recall
#
#     How did you hear about County College of Morris? [Social Media]  \
# 100                                                 No
# ...

# %%
df.sample() #sample database entry
# Out:
#                     Timestamp  Which course are you currently enrolled in?  \
# 19  2023/09/07 9:25:16 AM EST  CMP 135 Computer Concepts with Applications
#
#    How did you hear about County College of Morris? [CCM Web site]  \
# 19                                                 No
#
#    How did you hear about County College of Morris? [Social Media]  \
# 19                                                 No
#
#    How did you hear about County College of Morris? [Community Event]  \
# 19                                                 No
#
#    How did you hear about County College of Morris? [Family member or friend]  \
# 19                                                Yes
#
#    How did you hear about County College of Morris? [Current CCM student]  \
# 19                                                 No
#
#    How did you hear about County College of Morris? [CCM Alumni]  \
# 19                                                 No
#
# ...

# %%
df.info() #info for database entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 96 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        105 non-null    object
# ...

# %% [markdown]
# ## Cleaning/Analysis

# %% [markdown]
# ### Renamed all columns in the database

# %%
df.rename(columns= {'Which course are you currently enrolled in?':'Current_course_enrollment'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [CCM Web site]':'CCM_ad_Website'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Social Media]':'CCM_ad_Social_Media'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Community Event]':'CCM_ad_Community_Event'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Family member or friend]':'CCM_ad_Family/friend'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Current CCM student]':'CCM_ad_Current_Student'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [CCM Alumni]':'CCM_ad_Alumni'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [High School Teacher]':'CCM_ad_HS_Teacher'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [High School Counselor]':'CCM_ad_HS_Counselor'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [In-app advertisement]':'CCM_ad_In_App_Ad'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Employer]':'CCM_ad_Employer'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Billboard]':'CCM_ad_Billboard'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Television]':'CCM_ad_TV'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Radio]':'CCM_ad_Radio'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Home mailer]':'CCM_ad_Mail'}, inplace = True)
df.rename(columns= {'How did you hear about County College of Morris? [Other]':'CCM_ad_Other'}, inplace = True)

df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]':'Attendance_impact_Affordable_Cost'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]':'Attendance_impact_Location_Convenience'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]':'Attendance_impact_Program_Selection'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]':'Attendance_impact_Online_Offerings'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]':'Attendance_impact_Family/friend_Referral'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]':'Attendance_impact_Faculty/staff'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [College reputation]':'Attendance_impact_College_Reputation'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]':'Attendance_impact_Financial_Aid'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]':'Attendance_impact_Scholarships'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]':'Attendance_impact_Small_Class_Size'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]':'Attendance_impact_EC_Activities'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]':'Attendance_impact_Accepted_Transfer_Credits'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]':'Attendance_impact_Bad_Prev_College_Exp'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]':'Attendance_impact_NJ_Stars_Program'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]':'Attendance_impact_Credit_Transferability_to_4-year_Uni.'}, inplace = True)
df.rename(columns= {'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]':'Attendance_impact_College_Credits_During_HS'}, inplace = True)

df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]':'Open_house_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]':'Instant_decision_day_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]':'On_campus_info_session_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]':'Titans_Tuesday_virtual_session_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]':'Women_Who_Dare_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]':'Regional_college_fair_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]':'HS_Sharetime_info_session_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]':'Challenger_Program_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation]':'CyberSecurity_info_protection_program_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]':'HS_info_session_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]':'Campus_visit_with_HS_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]':'Individual_campus_visit_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]':'Workforce_Development_class_program_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]':'Corporate_training_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]':'Teen_Arts_Festival_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]':'Summer_Camp_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)
df.rename(columns= {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]':'Hour_of_Code_participation_for_CCM/Dept_of_Info_Tech_participation'}, inplace = True)

df.rename(columns= {'What motivated you to seek a computing class at CCM? [To keep current in computing skills]':'Comp_class_motivation[Current_computing_skills]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Curiosity]':'Comp_class_motivation[Curiosity]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Personal Enrichment]':'Comp_class_motivation[Personal_Enrichment]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Career Advancement]':'Comp_class_motivation[Career_Advancement]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Career Change]':'Comp_class_motivation[Career_Change]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Professional Development]':'Comp_class_motivation[Professional_Development]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Job Displacement]':'Comp_class_motivation[Job_Displacement]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Financial]':'Comp_class_motivation[Financial]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [Relocation]':'Comp_class_motivation[Relocation]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [IT Industry Certifications]':'Comp_class_motivation[IT_Industry_Certifications]'}, inplace = True)
df.rename(columns= {'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]':'Comp_class_motivation[degree_requirement]'}, inplace = True)

df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]':'Enrollment_impact_School_computing_class'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]':'Enrollment_impact_School_computing_related_club'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]':'Enrollment_impact_Computing_competition'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]':'Enrollment_impact_Afterschool_computing_program'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]':'Enrollment_impact_Summer_computing_program'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]':'Enrollment_impact_AP_course'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]':'Enrollment_impact_Dual_enrollment_computing_course'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]':'Enrollment_impact_Family/friend_influence'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]':'Enrollment_impact_Computing_field_family/friend'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]':'Enrollment_impact_HS_teacher/counselor'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]':'Enrollment_impact_Employer_influence'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM faculty member]':'Enrollment_impact_Faculty_member'}, inplace = True)
df.rename(columns= {'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM advisor/counselor]':'Enrollment_impact_Advisor/counselor'}, inplace = True)

df.rename(columns= {'What degree program are you currently enrolled in?':'Current_degree_enrollment'}, inplace = True)

df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [High school guidance counselor]':'Comp_class_info_source[HS_guidance_counselor]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [High School Teacher]':'Comp_class_info_source[HS_Teacher]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [CCM Information Technologies Website]':'Comp_class_info_source[CCM_Information_Technologies_Website]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [CCM Admissions]':'Comp_class_info_source[CCM_Admissions]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [CCM advisor/counselor]':'Comp_class_info_source[CCM_advisor/counselor]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [Employer]':'Comp_class_info_source[Employer]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [CCM Workforce Development]':'Comp_class_info_source[CCM_Workforce_Development]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [NJ Workforce Development Program]':'Comp_class_info_source[NJ_Workforce_Development_Program]'}, inplace = True)
df.rename(columns= {'Did you receive information about CCM computing classes from any of the following sources? [Other]':'Comp_class_info_source[Other]'}, inplace = True)

df.rename(columns= {'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?':'CS_Info_Tech/Game_Development_Courses_interest_level_1-5_1=low_5=high'}, inplace = True)

df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]':'Web_Development_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]':'Cyber_security_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]':'App_Development_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]':'Data_Analytics_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]':'Machine_Learning/AI_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]':'Comp_Programming_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]':'Game_Design_interest'}, inplace = True)
df.rename(columns= {'If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]':'Hardware_Installation/repair_interest'}, inplace = True)

df.rename(columns= {'Age ':'Age'}, inplace = True)

# %% [markdown]
# ### filled N/A values

# %%
df.fillna('Prefer not to say')
# Out:
#                       Timestamp                     Current_course_enrollment  \
# 0     2023/09/05 9:36:31 PM EST         CMP 101 Computer Information Literacy
# 1     2023/09/05 9:42:31 PM EST         CMP 101 Computer Information Literacy
# 2    2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 3    2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 4    2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
# ..                          ...                                           ...
# 100   2023/09/19 6:04:34 PM EST   CMP 135 Computer Concepts with Applications
# 101   2023/09/19 6:05:55 PM EST         CMP 101 Computer Information Literacy
# 102   2023/09/19 6:07:54 PM EST   CMP 135 Computer Concepts with Applications
# 103   2023/09/19 6:08:11 PM EST   CMP 135 Computer Concepts with Applications
# 104  2023/09/19 10:44:14 PM EST   CMP 135 Computer Concepts with Applications
#
# ...

# %%
df.replace('psychology , liberal arts','Psychology Studies', inplace = True)
df.replace('Human Resources/ Psychology','Psychology Studies', inplace = True)
df.replace('Psychology','Psychology Studies', inplace = True)

df.replace('Musical Theatre','Music Industry Skills', inplace = True)
df.replace('Music Technology','Music Industry Skills', inplace = True)
df.replace('Music recording','Music Industry Skills', inplace = True)

df.replace('Broadcasting Arts and Technology','Visual Performance Tech', inplace = True)
df.replace('Theatre Technology','Visual Performance Tech', inplace = True)

# %% [markdown]
# ### stripped column titles of blank spaces

# %%
df.columns.str.strip()
# Out:
# Index(['Timestamp', 'Current_course_enrollment', 'CCM_ad_Website',
#        'CCM_ad_Social_Media', 'CCM_ad_Community_Event', 'CCM_ad_Family/friend',
#        'CCM_ad_Current_Student', 'CCM_ad_Alumni', 'CCM_ad_HS_Teacher',
#        'CCM_ad_HS_Counselor', 'CCM_ad_In_App_Ad', 'CCM_ad_Employer',
#        'CCM_ad_Billboard', 'CCM_ad_TV', 'CCM_ad_Radio', 'CCM_ad_Mail',
#        'CCM_ad_Other', 'Attendance_impact_Affordable_Cost',
#        'Attendance_impact_Location_Convenience',
#        'Attendance_impact_Program_Selection',
#        'Attendance_impact_Online_Offerings',
#        'Attendance_impact_Family/friend_Referral',
#        'Attendance_impact_Faculty/staff',
#        'Attendance_impact_College_Reputation',
#        'Attendance_impact_Financial_Aid', 'Attendance_impact_Scholarships',
#        'Attendance_impact_Small_Class_Size', 'Attendance_impact_EC_Activities',
#        'Attendance_impact_Accepted_Transfer_Credits',
#        'Attendance_impact_Bad_Prev_College_Exp',
# ...

# %% [markdown]
# ### Created a for loop to show counts of each response for all columns

# %%
response_counts = {}
for column in df.columns:
    response_counts[column] = df[column].value_counts()

response_counts
# Out:
# {'Timestamp': Timestamp
#  2023/09/05 9:36:31 PM EST     1
#  2023/09/12 7:26:52 PM EST     1
#  2023/09/19 9:40:38 AM EST     1
#  2023/09/19 9:39:20 AM EST     1
#  2023/09/19 9:39:11 AM EST     1
#  2023/09/19 9:38:59 AM EST     1
#  2023/09/18 7:23:54 PM EST     1
#  2023/09/17 7:19:11 PM EST     1
#  2023/09/15 9:24:48 PM EST     1
#  2023/09/15 9:01:04 PM EST     1
#  2023/09/15 8:26:42 PM EST     1
#  2023/09/15 8:09:18 PM EST     1
#  2023/09/15 3:54:35 PM EST     1
#  2023/09/15 12:12:42 PM EST    1
#  2023/09/15 9:53:34 AM EST     1
#  2023/09/14 9:43:15 PM EST     1
#  2023/09/14 9:14:12 PM EST     1
#  2023/09/14 9:06:17 PM EST     1
#  2023/09/14 1:15:17 PM EST     1
#  2023/09/14 9:43:11 AM EST     1
#  2023/09/14 8:43:10 AM EST     1
#  2023/09/13 8:14:59 PM EST     1
#  2023/09/13 6:52:08 PM EST     1
#  2023/09/13 1:28:22 PM EST     1
#  2023/09/13 12:54:45 PM EST    1
#  2023/09/19 9:41:29 AM EST     1
#  2023/09/19 9:41:44 AM EST     1
# ...

# %% [markdown]
# ### Show counts of different computer class motivations based on age groups

# %%
age_CurrCompSkills_group = df.groupby('Age')['Comp_class_motivation[Current_computing_skills]'].count()
print('Age', '     :     ', 'Current Computing Skills-Motivation for CompClass')
print(age_CurrCompSkills_group)
print()

age_Curiosity_group = df.groupby('Age')['Comp_class_motivation[Curiosity]'].count()
print('Age', '     :     ', 'Curiosity-Motivation for CompClass')
print(age_Curiosity_group)
print()

age_PersEnrich_group = df.groupby('Age')['Comp_class_motivation[Personal_Enrichment]'].count()
print('Age', '     :     ', 'Personal Enrichment-Motivation for CompClass')
print(age_PersEnrich_group)
print()

age_CarAdvance_group = df.groupby('Age')['Comp_class_motivation[Career_Advancement]'].count()
print('Age', '     :     ', 'Career Advancement-Motivation for CompClass')
print(age_CarAdvance_group)
print()

age_CarChange_group = df.groupby('Age')['Comp_class_motivation[Career_Change]'].count()
print('Age', '     :     ', 'Career Change-Motivation for CompClass')
print(age_CarChange_group)
print()

age_ProDevelop_group = df.groupby('Age')['Comp_class_motivation_[Professional_Development]'].count()
print('Age', '     :     ', 'Professional Development-Motivation for CompClass')
print(age_ProDevelop_group)
print()

age_JopDisp_group = df.groupby('Age')['Comp_class_motivation[Job_Displacement]'].count()
print('Age', '     :     ', 'Job Displacement-Motivation for CompClass')
print(age_JopDisp_group)
print()

age_Financial_group = df.groupby('Age')['Comp_class_motivation[Financial]'].count()
print('Age', '     :     ', 'Financial-Motivation for CompClass')
print(age_Financial_group)
print()

age_Relocation_group = df.groupby('Age')['Comp_class_motivation[Relocation]'].count()
print('Age', '     :     ', 'Relocation-Motivation for CompClass')
print(age_Relocation_group)
print()

age_ITCert_group = df.groupby('Age')['Comp_class_motivation[IT_Industry_Certifications]'].count()
print('Age', '     :     ', 'IT Certifications Motivation for CompClass')
print(age_ITCert_group)
print()
# Out:
# Age      :      Current Computing Skills-Motivation for CompClass
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: Comp_class_motivation[Current_computing_skills], dtype: int64
#
# Age      :      Curiosity-Motivation for CompClass
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: Comp_class_motivation[Curiosity], dtype: int64
#
# Age      :      Personal Enrichment-Motivation for CompClass
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: Comp_class_motivation[Personal_Enrichment], dtype: int64
#
# Age      :      Career Advancement-Motivation for CompClass
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: Comp_class_motivation[Career_Advancement], dtype: int64
#
# ...

# %% [markdown]
# ### Show counts of different CS course impacts on enrollment based on gender

# %%
Gender_CompClass_Impact = df.groupby('Gender')['Enrollment_impact_School_computing_class'].count()
print('Gender', '     :     ', 'Computing Class EnrollmentImpact')
print(Gender_CompClass_Impact)
print()
print()

Gender_CompClub_Impact = df.groupby('Gender')['Enrollment_impact_School_computing_related_club'].count()
print('Gender', '     :     ', 'Computing Club EnrollmentImpact')
print(Gender_CompClub_Impact)
print()
print()

Gender_Competition_Impact = df.groupby('Gender')['Enrollment_impact_Computing_competition'].count()
print('Gender', '     :     ', 'Computing Competition EnrollmentImpact')
print(Gender_CompClub_Impact)
print()
print()

Gender_Afterschool_Impact = df.groupby('Gender')['Enrollment_impact_Afterschool_computing_program'].count()
print('Gender', '     :     ', 'Afterschool Computing Program EnrollmentImpact')
print(Gender_Afterschool_Impact)
print()
print()

Gender_SummerComp_Impact = df.groupby('Gender')['Enrollment_impact_Summer_computing_program'].count()
print('Gender', '     :     ', 'Summer Comp Program EnrollmentImpact')
print(Gender_SummerComp_Impact)
print()
print()

Gender_AP_Impact = df.groupby('Gender')['Enrollment_impact_AP_course'].count()
print('Gender', '     :     ', 'AP Course EnrollmentImpact')
print(Gender_AP_Impact)
print()
print()

Gender_DualEnrollment_Impact = df.groupby('Gender')['Enrollment_impact_Dual_enrollment_computing_course'].count()
print('Gender', '     :     ', 'Dual Enrollment Comp Course EnrollmentImpact')
print(Gender_DualEnrollment_Impact)
print()
print()

Gender_FamFriend_Impact = df.groupby('Gender')['Enrollment_impact_Family/friend_influence'].count()
print('Gender', '     :     ', 'Family/friend EnrollmentImpact')
print(Gender_FamFriend_Impact)
print()
print()

Gender_CompFamFriend_Impact = df.groupby('Gender')['Enrollment_impact_Computing_field_family/friend'].count()
print('Gender', '     :     ', 'Computing Field Family/friend EnrollmentImpact')
print(Gender_CompFamFriend_Impact)
print()
print()

Gender_HSstaff_Impact = df.groupby('Gender')['Enrollment_impact_HS_teacher/counselor'].count()
print('Gender', '     :     ', 'HS Teacher/Counselor EnrollmentImpact')
print(Gender_HSstaff_Impact)
print()
print()

Gender_Employer_Impact = df.groupby('Gender')['Enrollment_impact_Employer_influence'].count()
print('Gender', '     :     ', 'Employer EnrollmentImpact')
print(Gender_Employer_Impact)
print()
print()

Gender_Faculty_Impact = df.groupby('Gender')['Enrollment_impact_Faculty_member'].count()
print('Gender', '     :     ', 'Faculty Member EnrollmentImpact')
print(Gender_Faculty_Impact)
print()
print()

Gender_AdvisCouns_Impact = df.groupby('Gender')['Enrollment_impact_Advisor/counselor'].count()
print('Gender', '     :     ', 'Advisor/Counselor EnrollmentImpact')
print(Gender_AdvisCouns_Impact)
print()
# Out:
# Gender      :      Computing Class EnrollmentImpact
# Gender
# Man                  38
# Non-binary            2
# Prefer not to say     5
# Woman                47
# Name: Enrollment_impact_School_computing_class, dtype: int64
#
#
# Gender      :      Computing Club EnrollmentImpact
# Gender
# Man                  34
# Non-binary            2
# Prefer not to say     5
# Woman                46
# Name: Enrollment_impact_School_computing_related_club, dtype: int64
#
#
# Gender      :      Computing Competition EnrollmentImpact
# Gender
# Man                  34
# Non-binary            2
# Prefer not to say     5
# Woman                46
# Name: Enrollment_impact_School_computing_related_club, dtype: int64
#
#
# Gender      :      Afterschool Computing Program EnrollmentImpact
# Gender
# Man                  34
# Non-binary            2
# Prefer not to say     4
# Woman                45
# Name: Enrollment_impact_Afterschool_computing_program, dtype: int64
#
#
# ...

# %% [markdown]
# ### Show counts of different impacts on CCM attendance based on ethnic background

# %%
Ethnicity_AffCost_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Affordable_Cost'].count()
print('Ethnicity', '          :          ', 'Affordable Cost Impact on Attendance')
print(Ethnicity_AffCost_AttendImpact)
print()

Ethnicity_LocConvenience_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Location_Convenience'].count()
print('Ethnicity', '          :          ', 'Location Convenience Impact on Attendance')
print(Ethnicity_LocConvenience_AttendImpact)
print()

Ethnicity_ProgSelect_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Program_Selection'].count()
print('Ethnicity', '          :          ', 'Program Selection Impact on Attendance')
print(Ethnicity_ProgSelect_AttendImpact)
print()

Ethnicity_OnlOffer_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Online_Offerings'].count()
print('Ethnicity', '          :          ', 'Online Offerings Impact on Attendance')
print(Ethnicity_OnlOffer_AttendImpact)
print()

Ethnicity_FFRefer_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Family/friend_Referral'].count()
print('Ethnicity', '          :          ', 'Family/Friend Referral Impact on Attendance')
print(Ethnicity_FFRefer_AttendImpact)
print()

Ethnicity_FacStaff_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Faculty/staff'].count()
print('Ethnicity', '          :          ', 'Faculty/staff Impact on Attendance')
print(Ethnicity_FacStaff_AttendImpact)
print()

Ethnicity_CollegeRep_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_College_Reputation'].count()
print('Ethnicity', '          :          ', 'College Reputation Impact on Attendance')
print(Ethnicity_CollegeRep_AttendImpact)
print()

Ethnicity_FinAid_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Financial_Aid'].count()
print('Ethnicity', '          :          ', 'Financial Aid Impact on Attendance')
print(Ethnicity_FinAid_AttendImpact)
print()

Ethnicity_Scholarship_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Scholarships'].count()
print('Ethnicity', '          :          ', 'Scholarship Impact on Attendance')
print(Ethnicity_Scholarship_AttendImpact)
print()

Ethnicity_SmClass_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Small_Class_Size'].count()
print('Ethnicity', '          :          ', 'Small Class Size Impact on Attendance')
print(Ethnicity_SmClass_AttendImpact)
print()

Ethnicity_ECAct_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_EC_Activities'].count()
print('Ethnicity', '          :          ', 'EC Activites Impact on Attendance')
print(Ethnicity_ECAct_AttendImpact)
print()

Ethnicity_TransCred_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Accepted_Transfer_Credits'].count()
print('Ethnicity', '          :          ', 'Accepted Transfer Credits Impact on Attendance')
print(Ethnicity_TransCred_AttendImpact)
print()

Ethnicity_PrevCollExp_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Bad_Prev_College_Exp'].count()
print('Ethnicity', '          :          ', 'Prev College Experience Impact on Attendance')
print(Ethnicity_PrevCollExp_AttendImpact)
print()

Ethnicity_NJStars_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_NJ_Stars_Program'].count()
print('Ethnicity', '          :          ', 'NJ Stars Program Impact on Attendance')
print(Ethnicity_NJStars_AttendImpact)
print()

Ethnicity_Trans4Yr_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_Credit_Transferability_to_4-year_Uni.'].count()
print('Ethnicity', '          :          ', 'Credit Transferability to 4-year College Impact on Attendance')
print(Ethnicity_Trans4Yr_AttendImpact)
print()

Ethnicity_HSCollCred_AttendImpact = df.groupby('Race/ethnicity')['Attendance_impact_College_Credits_During_HS'].count()
print('Ethnicity', '          :          ', 'HS College Credits Impact on Attendance')
print(Ethnicity_HSCollCred_AttendImpact)
print()
# Out:
# Ethnicity           :           Affordable Cost Impact on Attendance
# Race/ethnicity
# Asian                                                     4
# Asian;White/Caucasian                                     2
# Asian;White/Caucasian;Multi-Racial                        1
# Black/African American                                    2
# Black/African American;White/Caucasian                    1
# Choose not to reply                                      10
# Hispanic or Latino                                       24
# Hispanic or Latino;Asian;White/Caucasian;Multi-Racial     1
# Hispanic or Latino;Black/African American                 1
# Hispanic or Latino;Multi-Racial                           1
# Hispanic or Latino;White/Caucasian                        4
# Multi-Racial                                              2
# White/Caucasian                                          49
# Name: Attendance_impact_Affordable_Cost, dtype: int64
#
# ...

# %% [markdown]
# ### Counts for each source of CCM advertisement

# %%
website_ad_counts = df['CCM_ad_Website'].value_counts()
print(website_counts)
print()
print()
socialmedia_ad_counts = df['CCM_ad_Social_Media'].value_counts()
print(socialmedia_ad_counts)
print()
print()
commevents_ad_counts = df['CCM_ad_Community_Event'].value_counts()
print(commevents_ad_counts)
print()
print()
familyfriend_ad_counts = df['CCM_ad_Family/friend'].value_counts()
print(familyfriend_ad_counts)
print()
print()
alumni_ad_counts = df['CCM_ad_Alumni'].value_counts()
print(alumni_ad_counts)
print()
print()
hsteacher_ad_counts = df['CCM_ad_HS_Teacher'].value_counts()
print(hsteacher_ad_counts)
print()
print()
hscounselor_ad_counts = df['CCM_ad_HS_Counselor'].value_counts()
print(hscounselor_ad_counts)
print()
print()
inappad_ad_counts = df['CCM_ad_In_App_Ad'].value_counts()
print(inappad_ad_counts)
print()
print()
employer_ad_counts = df['CCM_ad_Employer'].value_counts()
print(employer_ad_counts)
print()
print()
billboard_ad_counts = df['CCM_ad_Billboard'].value_counts()
print(billboard_ad_counts)
print()
print()
tv_ad_counts = df['CCM_ad_TV'].value_counts()
print(tv_ad_counts)
print()
print()
radio_ad_counts = df['CCM_ad_Radio'].value_counts()
print(radio_ad_counts)
print()
print()
mail_ad_counts = df['CCM_ad_Mail'].value_counts()
print(mail_ad_counts)
print()
print()
other_ad_counts = df['CCM_ad_Other'].value_counts()
print(other_ad_counts)
print()
print()
# Out:
# CCM_ad_Website
# No              60
# Yes             36
# Don't recall     9
# Name: count, dtype: int64
#
#
# CCM_ad_Social_Media
# No              69
# Yes             23
# Don't recall    13
# Name: count, dtype: int64
#
#
# CCM_ad_Community_Event
# No              76
# Yes             18
# Don't recall    11
# Name: count, dtype: int64
#
#
# CCM_ad_Family/friend
# Yes             75
# No              26
# Don't recall     4
# Name: count, dtype: int64
#
#
# CCM_ad_Alumni
# No              61
# Yes             35
# Don't recall     9
# Name: count, dtype: int64
#
#
# CCM_ad_HS_Teacher
# No              49
# Yes             45
# Don't recall    11
# Name: count, dtype: int64
#
#
# CCM_ad_HS_Counselor
# Yes             53
# No              43
# Don't recall     9
# Name: count, dtype: int64
#
#
# CCM_ad_In_App_Ad
# No              82
# Don't recall    12
# Yes             11
# Name: count, dtype: int64
#
#
# CCM_ad_Employer
# No              86
# Don't recall    14
# ...

# %%
Age_Impact_Website = df.groupby('Age')['CCM_ad_Website'].count()
print('Age','                :                ','Website Ad Source')
print(Age_Impact_Website)
print()

Age_Impact_SocialMedia = df.groupby('Age')['CCM_ad_Social_Media'].count()
print('Age','                :                ','Social Media Ad Source')
print(Age_Impact_SocialMedia)
print()

Age_Impact_CommunEvent = df.groupby('Age')['CCM_ad_Community_Event'].count()
print('Age','                :                ','Community Event Ad Source')
print(Age_Impact_CommunEvent)
print()

Age_Impact_FamFriend = df.groupby('Age')['CCM_ad_Family/friend'].count()
print('Age','                :                ','Family/friend Ad Source')
print(Age_Impact_FamFriend)
print()

Age_Impact_Student = df.groupby('Age')['CCM_ad_Current_Student'].count()
print('Age','                :                ','Current Student Ad Source')
print(Age_Impact_Student)
print()

Age_Impact_Alumni = df.groupby('Age')['CCM_ad_Alumni'].count()
print('Age','                :                ','Alumni Ad Source')
print(Age_Impact_Alumni)
print()

Age_Impact_HSTeacher = df.groupby('Age')['CCM_ad_HS_Teacher'].count()
print('Age','                :                ','HS Teacher Ad Source')
print(Age_Impact_HSTeacher)
print()

Age_Impact_HSCounselor = df.groupby('Age')['CCM_ad_HS_Counselor'].count()
print('Age','                :                ','HS Counselor Ad Source')
print(Age_Impact_HSCounselor)
print()

Age_Impact_InAppAd = df.groupby('Age')['CCM_ad_In_App_Ad'].count()
print('Age','                :                ','In App Ad Source')
print(Age_Impact_InAppAd)
print()

Age_Impact_Employer = df.groupby('Age')['CCM_ad_Employer'].count()
print('Age','                :                ','Employer Ad Source')
print(Age_Impact_Employer)
print()

Age_Impact_Billboard = df.groupby('Age')['CCM_ad_Billboard'].count()
print('Age','                :                ','Billboard Ad Source')
print(Age_Impact_Billboard)
print()

Age_Impact_TV = df.groupby('Age')['CCM_ad_TV'].count()
print('Age','                :                ','TV Ad Source')
print(Age_Impact_TV)
print()

Age_Impact_Radio = df.groupby('Age')['CCM_ad_Radio'].count()
print('Age','                :                ','Radio Ad Source')
print(Age_Impact_Radio)
print()
Age_Impact_Mail = df.groupby('Age')['CCM_ad_Mail'].count()
print('Age','                :                ','Mail Ad Source')
print(Age_Impact_Mail)
print()
Age_Impact_Other = df.groupby('Age')['CCM_ad_Other'].count()
print('Age','                :                ','Other Ad Source')
print(Age_Impact_Other)
print()
# Out:
# Age                 :                 Website Ad Source
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: CCM_ad_Website, dtype: int64
#
# Age                 :                 Social Media Ad Source
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: CCM_ad_Social_Media, dtype: int64
#
# Age                 :                 Community Event Ad Source
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: CCM_ad_Community_Event, dtype: int64
#
# Age                 :                 Family/friend Ad Source
# Age
# 18 and younger    12
# 19-20             54
# 21-24             21
# 25-34             10
# 35-64              8
# Name: CCM_ad_Family/friend, dtype: int64
#
# Age                 :                 Current Student Ad Source
# Age
# ...

# %% [markdown]
# ### Show counts of different CS interests based on students' current course

# %%
Course_WebDev_Interest = df.groupby('Current_course_enrollment')['Web_Development_interest'].count()
print('Current Course','               :               ','Web Development Interest')
print(Course_WebDev_Interest)
print()

Course_CybSec_Interest = df.groupby('Current_course_enrollment')['Cyber_security_interest'].count()
print('Current Course','               :               ','Cyber Security Interest')
print(Course_CybSec_Interest)
print()

Course_AppDev_Interest = df.groupby('Current_course_enrollment')['App_Development_interest'].count()
print('Current Course','               :               ','App Development Interest')
print(Course_AppDev_Interest)
print()

Course_DatAna_Interest = df.groupby('Current_course_enrollment')['Data_Analytics_interest'].count()
print('Current Course','               :               ','Data Analytics Interest')
print(Course_DatAna_Interest)
print()

Course_MachAI_Interest = df.groupby('Current_course_enrollment')['Machine_Learning/AI_interest'].count()
print('Current Course','               :               ','Machine Learning/AI Interest')
print(Course_MachAI_Interest)
print()

Course_ComPro_Interest = df.groupby('Current_course_enrollment')['Comp_Programming_interest'].count()
print('Current Course','               :               ','Computer Programming Interest')
print(Course_ComPro_Interest)
print()

Course_GamDes_Interest = df.groupby('Current_course_enrollment')['Game_Design_interest'].count()
print('Current Course','               :               ','Game Design Interest')
print(Course_GamDes_Interest)
print()

Course_HarInstRep_Interest = df.groupby('Current_course_enrollment')['Hardware_Installation/repair_interest'].count()
print('Current Course','               :               ','Hardware Installation/repairing Interest')
print(Course_GamDes_Interest)
print()
# Out:
# Current Course                :                Web Development Interest
# Current_course_enrollment
# CMP 101 Computer Information Literacy           31
# CMP 126 Computer Technology and Applications    28
# CMP 135 Computer Concepts with Applications     46
# Name: Web_Development_interest, dtype: int64
#
# Current Course                :                Cyber Security Interest
# Current_course_enrollment
# CMP 101 Computer Information Literacy           31
# CMP 126 Computer Technology and Applications    28
# CMP 135 Computer Concepts with Applications     46
# Name: Cyber_security_interest, dtype: int64
#
# Current Course                :                App Development Interest
# Current_course_enrollment
# CMP 101 Computer Information Literacy           31
# CMP 126 Computer Technology and Applications    28
# CMP 135 Computer Concepts with Applications     46
# Name: App_Development_interest, dtype: int64
#
# ...

# %% [markdown]
# ### Display full cleaned dataframe

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
# Out:
#                       Timestamp                     Current_course_enrollment  \
# 0     2023/09/05 9:36:31 PM EST         CMP 101 Computer Information Literacy
# 1     2023/09/05 9:42:31 PM EST         CMP 101 Computer Information Literacy
# 2    2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 3    2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 4    2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
# 5     2023/09/06 5:33:40 AM EST         CMP 101 Computer Information Literacy
# 6     2023/09/06 5:46:50 AM EST         CMP 101 Computer Information Literacy
# 7     2023/09/06 7:50:38 AM EST         CMP 101 Computer Information Literacy
# 8     2023/09/06 8:58:38 AM EST  CMP 126 Computer Technology and Applications
# 9    2023/09/06 11:02:09 AM EST  CMP 126 Computer Technology and Applications
# 10    2023/09/06 5:18:30 PM EST  CMP 126 Computer Technology and Applications
# ...

# %%
# very few outlier data entries but had trouble coding the removal of any rows/columms

# %% [markdown]
# ## Analysis Questions

# %% [markdown]
# 1.	Compare the race/ethnicity demographics of the different classes who answered the survey. Are there any significant differences?...
# Most of the individuals that participated in this survey were of either Caucasian or Hispanic descent.
# The smallest participant demographic included any of mixed race.
#
# 2.	Which degree programs are students enrolled in? The degree field needs to be cleaned and condensed into a smaller number of categories.
# For example, all the engineering majors should be collapsed into a single engineering category....
# Students are enrolled in the one of the following:
# 'Nursing', 'early childhood education', 'liberal arts', 'criminal justice', 'psychology, liberal arts', 'child and family studies',
# 'exercise science', 'radiography', 'theatre technology', 'human resources/psychology', 'broadcasting arts and technology', 'communication',
# 'psychology', 'world language', 'musical theatre', 'music technology', 'music recording', 'fire science technology', 'public health'.
# However, I believe any degrees involving psychology can be combined, visual broadcasting and theatre, and any music tech/music recording/music theatre majors.
#
# 3.	To determine how best to advertise the college to a broader portion of the public, which method for advertisement of CCM was the most
# successful? Which was least successful?...
# According to the data, word of mouth through a family member or friend was the most successful way for advertising CCM to prospective students.
# On the other hand, advertisement via radio or from an employer were the least successful methods.
# Because the most popular method is not one that can be controlled by a expanding any one form of advertising,
# the best way would be to increase all means of university promotion.
#
# 4.	To help in determining which demographic advertising should be focused on, which field was the most motivational towards students considering taking CCM computing classes? Which was least?...
# Aside from having a computing course as a requirement, students seeking updated computing skills were the most motivated to register.
# Therefore, it would be the best option to market and advertise towards incoming students with computer science related majors,
# students with undeclared majors, or students looking to change their major.
